# %%
include("../ToolBox/ToolBox.jl")
import FileIO
using .ToolBox

# %%
# Path 
master_data_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/measurement/s1a-iw3-slc-vv-20190929t170934-20190929t170959-029239-035263-006.tiff"
master_meta_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/annotation/s1a-iw3-slc-vv-20190929t170934-20190929t170959-029239-035263-006.xml"
# Out:
# "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/annotation/s1a-iw3-slc-vv-20190929t170934-20190929t170959-029239-035263-006.xml"

# %%
meta = Load.slc_meta(master_meta_path);

# %%
master_view = [8000:10000,1000:6000]
master_data = Load.slc_data(master_data_path,master_view);

# %%
SlcUtil.show_img(master_data[end:-1:1,1:4:end])
# Out:
# 2001×1251 Array{Gray{Float64},2} with eltype ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.620263)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.486463)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.576954)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.694947)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.676273)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.721178)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.766171)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.507817)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.604108)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.846303)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.297307)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.423689)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.596182)
# ...

# %%
# Path 
master_data_path2 = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/measurement/s1a-iw2-slc-vv-20190929t170933-20190929t170958-029239-035263-005.tiff"
master_meta_path2 = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/annotation/s1a-iw2-slc-vv-20190929t170933-20190929t170958-029239-035263-005.xml"
# Out:
# "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/annotation/s1a-iw2-slc-vv-20190929t170933-20190929t170958-029239-035263-005.xml"

# %%
meta2 = Load.slc_meta(master_meta_path2);

# %%
meta2["samples_per_burst"]
# Out:
# 25957

# %%
master_view2 = [8400:9700,20000:25950]
master_data2 = Load.slc_data(master_data_path2,master_view2);

# %%
# To right Fårup Sø
# bottom right Skærsø
SlcUtil.show_img(master_data2[end:-1:1,1:4:end])
# Out:
# 1301×1488 Array{Gray{Float64},2} with eltype ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.824133)   Gray{Float64}(0.191999)   …  Gray{Float64}(0.0)
#  Gray{Float64}(0.811218)   Gray{Float64}(0.188851)      Gray{Float64}(0.0)
#  Gray{Float64}(0.420907)   Gray{Float64}(0.179451)      Gray{Float64}(0.0)
#  Gray{Float64}(0.184761)   Gray{Float64}(0.146191)      Gray{Float64}(0.0)
#  Gray{Float64}(0.1503)     Gray{Float64}(0.237646)      Gray{Float64}(0.0)
#  Gray{Float64}(0.40862)    Gray{Float64}(0.358902)   …  Gray{Float64}(0.0)
#  Gray{Float64}(0.383015)   Gray{Float64}(0.168041)      Gray{Float64}(0.0)
#  Gray{Float64}(0.0983385)  Gray{Float64}(0.169929)      Gray{Float64}(0.0)
#  Gray{Float64}(0.385733)   Gray{Float64}(0.225836)      Gray{Float64}(0.0)
#  Gray{Float64}(0.34879)    Gray{Float64}(0.426952)      Gray{Float64}(0.0)
#  Gray{Float64}(0.206745)   Gray{Float64}(0.244782)   …  Gray{Float64}(0.0)
#  Gray{Float64}(0.332873)   Gray{Float64}(0.310507)      Gray{Float64}(0.0)
# ...
