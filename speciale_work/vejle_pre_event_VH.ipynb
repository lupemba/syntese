# %%
include("../ToolBox/ToolBox.jl")
import JLD
import FileIO
using .ToolBox
using .Geometry
using Colors

# %%
# Paths 
master_data_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/measurement/s1a-iw3-slc-vh-20190929t170934-20190929t170959-029239-035263-003.tiff"
master_meta_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/annotation/s1a-iw3-slc-vh-20190929t170934-20190929t170959-029239-035263-003.xml"
master_pod_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_OPER_AUX_POEORB_OPOD_20191019T120656_V20190928T225942_20190930T005942.EOF"

slave_data_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190917T170931_20190917T170958_029064_034C5E_2484.SAFE/measurement/s1a-iw3-slc-vh-20190917t170933-20190917t170958-029064-034c5e-003.tiff"
slave_meta_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190917T170931_20190917T170958_029064_034C5E_2484.SAFE/annotation/s1a-iw3-slc-vh-20190917t170933-20190917t170958-029064-034c5e-003.xml"
slave_pod_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_OPER_AUX_POEORB_OPOD_20191007T120623_V20190916T225942_20190918T005942.EOF"
#dem
dem_path = "/Users/simon/Data/DEM/denmark.jld";

# %%
master_view = [8000:10000,1200:6000]
# Out:
# 2-element Array{UnitRange{Int64},1}:
#  8000:10000
#  1200:6000

# %%
# load meta and pod
master_meta = Load.slc_meta(master_meta_path);
master_precise_orbit = Load.precise_orbit(master_pod_path,master_meta["t_0"]);
slave_meta = Load.slc_meta(slave_meta_path);
slave_precise_orbit = Load.precise_orbit(slave_pod_path,slave_meta["t_0"]);

meta = (master_meta,slave_meta)
precise_orbit = (master_precise_orbit,slave_precise_orbit);

# %%
pad = 0.1
dem = JLD.load(dem_path);
footprint = SlcUtil.footprint(master_meta, master_view)
latlon_window = ((minimum(footprint[1]), maximum(footprint[1])), (minimum(footprint[2]), maximum(footprint[2])))
idx1 =(latlon_window[1][1] - pad) .<dem["lat"].< (latlon_window[1][2] + pad)
idx2 =(latlon_window[2][1] - pad) .<dem["lon"].< (latlon_window[2][2] + pad)
dem = (dem["lat"][idx1], dem["lon"][idx2], dem["height"][idx1,idx2]);
dem[3][dem[3].<0] .= 0;

# %%
slave_data,flat,lut =  coregister_slave(master_view,slave_data_path,meta,precise_orbit,dem)
slave_data,mosaic_view = SlcUtil.mosaic(slave_data,master_view,meta[1]);
flat,mosaic_view = SlcUtil.mosaic(flat,master_view,meta[1]);

master_data = Load.slc_data(master_data_path,master_view);
master_data,mosaic_view = SlcUtil.mosaic(master_data,master_view,meta[1]);

# %%
kernel = ones(4,14)
complex_coherence, master_intensity, slave_intensity, lines, samples = SlcUtil.complex_coherence(master_data, slave_data, flat, kernel, mosaic_view);

# %%
coherence_img = Gray.(abs.(complex_coherence[1:2:end,1:7:end]))
# Out:
# 911×683 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.20175)    …  Gray{Float64}(0.56598)
#  Gray{Float64}(0.288172)      Gray{Float64}(0.698041)
#  Gray{Float64}(0.0691326)     Gray{Float64}(0.733558)
#  Gray{Float64}(0.110824)      Gray{Float64}(0.633049)
#  Gray{Float64}(0.228343)      Gray{Float64}(0.309438)
#  Gray{Float64}(0.42854)    …  Gray{Float64}(0.0280613)
#  Gray{Float64}(0.405087)      Gray{Float64}(0.176643)
#  Gray{Float64}(0.254444)      Gray{Float64}(0.108524)
#  Gray{Float64}(0.169526)      Gray{Float64}(0.252209)
#  Gray{Float64}(0.171498)      Gray{Float64}(0.34279)
#  Gray{Float64}(0.051285)   …  Gray{Float64}(0.364266)
#  Gray{Float64}(0.419919)      Gray{Float64}(0.502599)
#  Gray{Float64}(0.254661)      Gray{Float64}(0.46011)
#  ⋮                         ⋱
#  Gray{Float64}(0.147257)      Gray{Float64}(0.11143)
#  Gray{Float64}(0.250596)   …  Gray{Float64}(0.330675)
#  Gray{Float64}(0.382361)      Gray{Float64}(0.321502)
#  Gray{Float64}(0.424751)      Gray{Float64}(0.395505)
#  Gray{Float64}(0.329027)      Gray{Float64}(0.463295)
#  Gray{Float64}(0.103796)      Gray{Float64}(0.397585)
#  Gray{Float64}(0.282794)   …  Gray{Float64}(0.388951)
#  Gray{Float64}(0.371126)      Gray{Float64}(0.372164)
#  Gray{Float64}(0.334437)      Gray{Float64}(0.310578)
#  Gray{Float64}(0.256315)      Gray{Float64}(0.128956)
#  Gray{Float64}(0.0643567)     Gray{Float64}(0.319007)
#  Gray{Float64}(0.129639)   …  Gray{Float64}(0.290866)

# %%
intensity = SlcUtil.show_img(master_intensity[1:2:end,1:7:end].-minimum(minimum(master_intensity[1:2:end,1:7:end])))
# Out:
# 911×683 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.395335)  Gray{Float64}(0.36429)   …  Gray{Float64}(0.611585)
#  Gray{Float64}(0.461613)  Gray{Float64}(0.463338)     Gray{Float64}(0.855628)
#  Gray{Float64}(0.477129)  Gray{Float64}(0.490075)     Gray{Float64}(0.774423)
#  Gray{Float64}(0.505369)  Gray{Float64}(0.537133)     Gray{Float64}(0.4894)
#  Gray{Float64}(0.589555)  Gray{Float64}(0.787443)     Gray{Float64}(0.51553)
#  Gray{Float64}(0.865248)  Gray{Float64}(1.0)       …  Gray{Float64}(0.410878)
#  Gray{Float64}(0.844027)  Gray{Float64}(0.844213)     Gray{Float64}(0.290913)
#  Gray{Float64}(0.73896)   Gray{Float64}(0.709391)     Gray{Float64}(0.314452)
#  Gray{Float64}(0.613749)  Gray{Float64}(0.651765)     Gray{Float64}(0.414662)
#  Gray{Float64}(0.390981)  Gray{Float64}(0.662276)     Gray{Float64}(0.345265)
#  Gray{Float64}(0.251936)  Gray{Float64}(0.631673)  …  Gray{Float64}(0.19189)
#  Gray{Float64}(0.29868)   Gray{Float64}(0.374588)     Gray{Float64}(0.263335)
#  Gray{Float64}(0.54391)   Gray{Float64}(0.32715)      Gray{Float64}(0.354174)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.208262)  Gray{Float64}(0.19984)      Gray{Float64}(0.399687)
#  Gray{Float64}(0.181205)  Gray{Float64}(0.130229)  …  Gray{Float64}(0.323011)
#  Gray{Float64}(0.15124)   Gray{Float64}(0.12974)      Gray{Float64}(0.38734)
#  Gray{Float64}(0.214759)  Gray{Float64}(0.216533)     Gray{Float64}(0.490865)
#  Gray{Float64}(0.237598)  Gray{Float64}(0.267604)     Gray{Float64}(0.453716)
#  Gray{Float64}(0.154074)  Gray{Float64}(0.194629)     Gray{Float64}(0.455307)
#  Gray{Float64}(0.160588)  Gray{Float64}(0.177711)  …  Gray{Float64}(0.384215)
#  Gray{Float64}(0.234766)  Gray{Float64}(0.324378)     Gray{Float64}(0.444047)
#  Gray{Float64}(0.224119)  Gray{Float64}(0.335091)     Gray{Float64}(0.47796)
#  Gray{Float64}(0.137107)  Gray{Float64}(0.208376)     Gray{Float64}(0.377206)
#  Gray{Float64}(0.181328)  Gray{Float64}(0.312905)     Gray{Float64}(0.423978)
#  Gray{Float64}(0.348709)  Gray{Float64}(0.473143)  …  Gray{Float64}(0.374396)

# %%
 SlcUtil.show_img(slave_intensity[1:2:end,1:7:end].-minimum(minimum(master_intensity[1:2:end,1:7:end])))
# Out:
# 911×683 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.232274)   …  Gray{Float64}(0.683409)
#  Gray{Float64}(0.239688)      Gray{Float64}(1.0)
#  Gray{Float64}(0.40465)       Gray{Float64}(1.0)
#  Gray{Float64}(0.536249)      Gray{Float64}(0.772484)
#  Gray{Float64}(0.394793)      Gray{Float64}(0.739762)
#  Gray{Float64}(0.21225)    …  Gray{Float64}(0.634726)
#  Gray{Float64}(0.180752)      Gray{Float64}(0.350726)
#  Gray{Float64}(0.17536)       Gray{Float64}(0.352658)
#  Gray{Float64}(0.207672)      Gray{Float64}(0.309213)
#  Gray{Float64}(0.255877)      Gray{Float64}(0.301843)
#  Gray{Float64}(0.226707)   …  Gray{Float64}(0.213432)
#  Gray{Float64}(0.294044)      Gray{Float64}(0.350649)
#  Gray{Float64}(0.387224)      Gray{Float64}(0.372913)
#  ⋮                         ⋱
#  Gray{Float64}(0.0702527)     Gray{Float64}(0.125248)
#  Gray{Float64}(0.0889649)  …  Gray{Float64}(0.120103)
#  Gray{Float64}(0.0644179)     Gray{Float64}(0.0621231)
#  Gray{Float64}(0.069323)      Gray{Float64}(0.0828706)
#  Gray{Float64}(0.0693146)     Gray{Float64}(0.0906196)
#  Gray{Float64}(0.056562)      Gray{Float64}(0.0981732)
#  Gray{Float64}(0.0626061)  …  Gray{Float64}(0.099461)
#  Gray{Float64}(0.0694181)     Gray{Float64}(0.0892355)
#  Gray{Float64}(0.0804388)     Gray{Float64}(0.0669958)
#  Gray{Float64}(0.0657036)     Gray{Float64}(0.0579314)
#  Gray{Float64}(0.0760507)     Gray{Float64}(0.0745729)
#  Gray{Float64}(0.112359)   …  Gray{Float64}(0.0705653)

# %%
JLD.save("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/pre_master_VH.jld", "data", master_intensity)
JLD.save("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/pre_coherence_VH.jld", "data", complex_coherence)
JLD.save("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/pre_slave_VH.jld", "data", slave_intensity)
JLD.save("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/pre_lut.jld", "lut", lut)
