# %%
include("../ToolBox/ToolBox.jl")
import JLD
import FileIO
using .ToolBox
using .Geometry
using Colors

# %%
master_folder = "/home/data/simon/data/143_houston_summer2017/S1A_IW_SLC__1SDV_20170824T122248_20170824T122318_018065_01E54E_5C27.SAFE"
master_data_path, master_meta_path, master_cal_path = Load.slc_paths(master_folder, "VV",1)
# Out:
# ("/home/data/simon/data/143_houston_summer2017/S1B_IW_SLC__1SDV_20170830T122203_20170830T122233_007169_00CA2C_C92C.SAFE/measurement/s1b-iw1-slc-vv-20170830t122203-20170830t122231-007169-00ca2c-004.tiff", "/home/data/simon/data/143_houston_summer2017/S1B_IW_SLC__1SDV_20170830T122203_20170830T122233_007169_00CA2C_C92C.SAFE/annotation/s1b-iw1-slc-vv-20170830t122203-20170830t122231-007169-00ca2c-004.xml", "/home/data/simon/data/143_houston_summer2017/S1B_IW_SLC__1SDV_20170830T122203_20170830T122233_007169_00CA2C_C92C.SAFE/annotation/calibration/calibration-s1b-iw1-slc-vv-20170830t122203-20170830t122231-007169-00ca2c-004.xml")

# %%
master_view = [7000:10000,5000:20500];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[:,end:-4:1])
# Out:
# 3001×3876 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.234023)   …  Gray{Float64}(0.210106)
#  Gray{Float64}(0.176838)      Gray{Float64}(0.0895756)
#  Gray{Float64}(0.0786436)     Gray{Float64}(0.151268)
#  Gray{Float64}(0.11498)       Gray{Float64}(0.163589)
#  Gray{Float64}(0.0162888)     Gray{Float64}(0.0256659)
#  Gray{Float64}(0.104824)   …  Gray{Float64}(0.0577878)
#  Gray{Float64}(0.090793)      Gray{Float64}(0.116757)
#  Gray{Float64}(0.298824)      Gray{Float64}(0.0847471)
#  Gray{Float64}(0.433723)      Gray{Float64}(0.225745)
#  Gray{Float64}(0.0780597)     Gray{Float64}(0.159626)
#  Gray{Float64}(0.123423)   …  Gray{Float64}(0.0220205)
#  Gray{Float64}(0.118004)      Gray{Float64}(0.163365)
#  Gray{Float64}(0.118314)      Gray{Float64}(0.127184)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.313759)      Gray{Float64}(0.0470541)
#  Gray{Float64}(0.243563)   …  Gray{Float64}(0.102842)
#  Gray{Float64}(0.154943)      Gray{Float64}(0.13544)
# ...

# %%
master_view = [7600:9500,7000:15000];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[:,end:-4:1])
# Out:
# 1901×2001 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.112291)   …  Gray{Float64}(0.192928)
#  Gray{Float64}(0.0271894)     Gray{Float64}(0.147983)
#  Gray{Float64}(0.224489)      Gray{Float64}(0.193776)
#  Gray{Float64}(0.0498278)     Gray{Float64}(0.103129)
#  Gray{Float64}(0.220635)      Gray{Float64}(0.153193)
#  Gray{Float64}(0.0206258)  …  Gray{Float64}(0.246847)
#  Gray{Float64}(0.256545)      Gray{Float64}(0.149577)
#  Gray{Float64}(0.187129)      Gray{Float64}(0.233071)
#  Gray{Float64}(0.0925811)     Gray{Float64}(0.135947)
#  Gray{Float64}(0.185426)      Gray{Float64}(0.292577)
#  Gray{Float64}(0.287964)   …  Gray{Float64}(0.306022)
#  Gray{Float64}(0.282573)      Gray{Float64}(0.224614)
#  Gray{Float64}(0.628438)      Gray{Float64}(0.319119)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.397641)      Gray{Float64}(0.435943)
#  Gray{Float64}(0.291944)   …  Gray{Float64}(0.360476)
#  Gray{Float64}(0.157037)      Gray{Float64}(0.145031)
# ...

# %%
master_view = [7600:9500,11000:19000];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[:,end:-4:1])
# Out:
# 1901×2001 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.253986)   …  Gray{Float64}(0.25033)
#  Gray{Float64}(0.532817)      Gray{Float64}(0.163183)
#  Gray{Float64}(0.333161)      Gray{Float64}(0.181781)
#  Gray{Float64}(0.189693)      Gray{Float64}(0.0848602)
#  Gray{Float64}(0.387048)      Gray{Float64}(0.0566032)
#  Gray{Float64}(0.778344)   …  Gray{Float64}(0.0429391)
#  Gray{Float64}(0.48137)       Gray{Float64}(0.122719)
#  Gray{Float64}(0.436027)      Gray{Float64}(0.109543)
#  Gray{Float64}(0.689972)      Gray{Float64}(0.0799072)
#  Gray{Float64}(0.381423)      Gray{Float64}(0.0801433)
#  Gray{Float64}(0.392947)   …  Gray{Float64}(0.204252)
#  Gray{Float64}(0.54593)       Gray{Float64}(0.206332)
#  Gray{Float64}(0.537688)      Gray{Float64}(0.16514)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.458793)      Gray{Float64}(0.229611)
#  Gray{Float64}(0.235845)   …  Gray{Float64}(0.176122)
#  Gray{Float64}(0.0627446)     Gray{Float64}(0.256694)
# ...

# %%
master_folder = "/home/data/simon/data/143_houston_summer2017/S1A_IW_SLC__1SDV_20170824T122248_20170824T122318_018065_01E54E_5C27.SAFE"
master_data_path, master_meta_path, master_cal_path = Load.slc_paths(master_folder, "VV",2)
# Out:
# ("/home/data/simon/data/143_houston_summer2017/S1A_IW_SLC__1SDV_20170824T122248_20170824T122318_018065_01E54E_5C27.SAFE/measurement/s1a-iw2-slc-vv-20170824t122249-20170824t122317-018065-01e54e-005.tiff", "/home/data/simon/data/143_houston_summer2017/S1A_IW_SLC__1SDV_20170824T122248_20170824T122318_018065_01E54E_5C27.SAFE/annotation/s1a-iw2-slc-vv-20170824t122249-20170824t122317-018065-01e54e-005.xml", "/home/data/simon/data/143_houston_summer2017/S1A_IW_SLC__1SDV_20170824T122248_20170824T122318_018065_01E54E_5C27.SAFE/annotation/calibration/calibration-s1a-iw2-slc-vv-20170824t122249-20170824t122317-018065-01e54e-005.xml")

# %%
master_view = [7000:9500,500:9000];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[:,end:-4:1])
# Out:
# 2501×2126 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.448616)   …  Gray{Float64}(1.0)
#  Gray{Float64}(0.510276)      Gray{Float64}(0.842954)
#  Gray{Float64}(0.334069)      Gray{Float64}(0.107153)
#  Gray{Float64}(0.228494)      Gray{Float64}(0.161493)
#  Gray{Float64}(0.470465)      Gray{Float64}(0.22984)
#  Gray{Float64}(0.512736)   …  Gray{Float64}(0.150544)
#  Gray{Float64}(0.254181)      Gray{Float64}(0.163288)
#  Gray{Float64}(0.489933)      Gray{Float64}(0.235073)
#  Gray{Float64}(0.360207)      Gray{Float64}(0.221269)
#  Gray{Float64}(0.0695175)     Gray{Float64}(0.262693)
#  Gray{Float64}(0.124156)   …  Gray{Float64}(0.187826)
#  Gray{Float64}(0.0712927)     Gray{Float64}(0.12233)
#  Gray{Float64}(0.0348784)     Gray{Float64}(0.0410257)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.472444)      Gray{Float64}(0.18279)
#  Gray{Float64}(0.325145)   …  Gray{Float64}(0.216934)
#  Gray{Float64}(0.238905)      Gray{Float64}(0.485937)
# ...

# %%
master_data_path, master_meta_path, master_cal_path = Load.slc_paths(master_folder, "VV",1)
master_view = [7600:9500,14000:27000];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[:,end:-4:1])
# Out:
# 1901×1629 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.0028564)   …  Gray{Float64}(0.145928)
#  Gray{Float64}(0.0)            Gray{Float64}(0.108881)
#  Gray{Float64}(0.0)            Gray{Float64}(0.257155)
#  Gray{Float64}(0.00403956)     Gray{Float64}(0.336582)
#  Gray{Float64}(0.0)            Gray{Float64}(0.0959766)
#  Gray{Float64}(0.0)         …  Gray{Float64}(0.213448)
#  Gray{Float64}(0.0028564)      Gray{Float64}(0.202865)
#  Gray{Float64}(0.0028564)      Gray{Float64}(0.208223)
#  Gray{Float64}(0.0028564)      Gray{Float64}(0.307391)
#  Gray{Float64}(0.0028564)      Gray{Float64}(0.133367)
#  Gray{Float64}(0.0028564)   …  Gray{Float64}(0.172452)
#  Gray{Float64}(0.00403956)     Gray{Float64}(0.177924)
#  Gray{Float64}(0.0)            Gray{Float64}(0.269911)
#  ⋮                          ⋱
#  Gray{Float64}(0.0263347)      Gray{Float64}(0.278524)
#  Gray{Float64}(0.0199948)   …  Gray{Float64}(0.169661)
# ...

# %%
size(master_data)
# Out:
# (1901, 2513)

# %%
master_meta["samples_per_burst"]
# Out:
# UndefVarError: master_meta not defined
#
# Stacktrace:
#  [1] top-level scope at In[10]:1

# %%
master_data
# Out:
# 0×6801 Array{Complex{Float64},2}

# %%
master_data = Load.slc_data(master_data_path,master_view);
