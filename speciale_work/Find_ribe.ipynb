# %%
include("../ToolBox/ToolBox.jl")
import JLD
import FileIO
using .ToolBox
using .Geometry
using Colors

# %%
6*1500
# Out:
# 9000

# %%
data/117_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200220T170928_20200220T170955_031339_039B3F_8FCB.SAFE

# %%
master_folder = "/home/data/simon/data/117_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200220T170928_20200220T170955_031339_039B3F_8FCB.SAFE"
master_data_path, master_meta_path, master_cal_path = Load.slc_paths(master_folder, "VH",2)
# Out:
# ("/home/data/simon/data/117_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200220T170928_20200220T170955_031339_039B3F_8FCB.SAFE/measurement/s1a-iw2-slc-vh-20200220t170929-20200220t170954-031339-039b3f-002.tiff", "/home/data/simon/data/117_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200220T170928_20200220T170955_031339_039B3F_8FCB.SAFE/annotation/s1a-iw2-slc-vh-20200220t170929-20200220t170954-031339-039b3f-002.xml", "/home/data/simon/data/117_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200220T170928_20200220T170955_031339_039B3F_8FCB.SAFE/annotation/calibration/calibration-s1a-iw2-slc-vh-20200220t170929-20200220t170954-031339-039b3f-002.xml")

# %%
master_view = [5400:8400,8000:18000];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[:,1:4:end])
# Out:
# 3001×2501 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.234909)   …  Gray{Float64}(0.162398)
#  Gray{Float64}(0.111493)      Gray{Float64}(0.235623)
#  Gray{Float64}(0.0943561)     Gray{Float64}(0.394188)
#  Gray{Float64}(0.0869437)     Gray{Float64}(0.563832)
#  Gray{Float64}(0.0697961)     Gray{Float64}(0.291258)
#  Gray{Float64}(0.102464)   …  Gray{Float64}(0.209188)
#  Gray{Float64}(0.122957)      Gray{Float64}(0.379754)
#  Gray{Float64}(0.0467309)     Gray{Float64}(0.194844)
#  Gray{Float64}(0.136243)      Gray{Float64}(0.483648)
#  Gray{Float64}(0.181914)      Gray{Float64}(0.421675)
#  Gray{Float64}(0.157675)   …  Gray{Float64}(0.156069)
#  Gray{Float64}(0.116647)      Gray{Float64}(0.343523)
#  Gray{Float64}(0.0921038)     Gray{Float64}(0.330437)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.837202)      Gray{Float64}(0.62696)
#  Gray{Float64}(0.553686)   …  Gray{Float64}(0.428491)
#  Gray{Float64}(0.577956)      Gray{Float64}(0.431616)
# ...
