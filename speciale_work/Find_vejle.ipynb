# %%
include("../ToolBox/ToolBox.jl")
import JLD
import FileIO
using .ToolBox
using .Geometry
using Colors

# %%
1500*4
# Out:
# 6000

# %%
master_folder = "/Users/simon/Data/Sentinel/vejle_2020/S1B_IW_SLC__1SDV_20200211T053200_20200211T053227_020217_026479_5817.SAFE";
master_view = [6200:8000,9000:19000]
 master_data_path, master_meta_path, master_cal_path = Load.slc_paths(master_folder, "VV",3)
# Out:
# ("/Users/simon/Data/Sentinel/vejle_2020/S1B_IW_SLC__1SDV_20200211T053200_20200211T053227_020217_026479_5817.SAFE/measurement/s1b-iw3-slc-vv-20200211t053201-20200211t053226-020217-026479-006.tiff", "/Users/simon/Data/Sentinel/vejle_2020/S1B_IW_SLC__1SDV_20200211T053200_20200211T053227_020217_026479_5817.SAFE/annotation/s1b-iw3-slc-vv-20200211t053201-20200211t053226-020217-026479-006.xml", "/Users/simon/Data/Sentinel/vejle_2020/S1B_IW_SLC__1SDV_20200211T053200_20200211T053227_020217_026479_5817.SAFE/annotation/calibration/calibration-s1b-iw3-slc-vv-20200211t053201-20200211t053226-020217-026479-006.xml")

# %%
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[:,end:-4:1])
# Out:
# 1801×2501 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.537812)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.54188)      Gray{Float64}(0.498571)
#  Gray{Float64}(0.529764)     Gray{Float64}(0.352287)
#  Gray{Float64}(0.241362)     Gray{Float64}(0.485289)
#  Gray{Float64}(0.320503)     Gray{Float64}(1.0)
#  Gray{Float64}(0.359205)  …  Gray{Float64}(0.90667)
#  Gray{Float64}(0.23309)      Gray{Float64}(0.392236)
#  Gray{Float64}(0.315936)     Gray{Float64}(0.564882)
#  Gray{Float64}(0.180574)     Gray{Float64}(0.907372)
#  Gray{Float64}(0.224608)     Gray{Float64}(0.471879)
#  Gray{Float64}(0.16607)   …  Gray{Float64}(0.0600542)
#  Gray{Float64}(0.170979)     Gray{Float64}(0.032569)
#  Gray{Float64}(0.358495)     Gray{Float64}(0.360325)
#  ⋮                        ⋱  ⋮
#  Gray{Float64}(0.096175)     Gray{Float64}(0.127727)
#  Gray{Float64}(0.435913)  …  Gray{Float64}(0.125802)
#  Gray{Float64}(0.27674)      Gray{Float64}(0.119843)
# ...

# %%
master_folder = "/Users/simon/Data/Sentinel/vejle_2020/S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.SAFE"
master_data_path, master_meta_path, master_cal_path = Load.slc_paths(master_folder, "VH",3)
# Out:
# ("/Users/simon/Data/Sentinel/vejle_2020/S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.SAFE/measurement/s1a-iw3-slc-vh-20200217t053254-20200217t053319-031288-03996e-003.tiff", "/Users/simon/Data/Sentinel/vejle_2020/S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.SAFE/annotation/s1a-iw3-slc-vh-20200217t053254-20200217t053319-031288-03996e-003.xml", "/Users/simon/Data/Sentinel/vejle_2020/S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.SAFE/annotation/calibration/calibration-s1a-iw3-slc-vh-20200217t053254-20200217t053319-031288-03996e-003.xml")

# %%
master_view = [5:2000,7000:20000];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[:,end:-4:1])
# Out:
# 1996×3251 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.0)        …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0103556)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.284355)      Gray{Float64}(0.224026)
#  Gray{Float64}(0.414224)   …  Gray{Float64}(0.0327473)
#  Gray{Float64}(0.453878)      Gray{Float64}(0.344236)
#  Gray{Float64}(0.307894)      Gray{Float64}(0.408095)
# ...

# %% [markdown]
# ## Vejle 2

# %%
master_folder = "/Users/simon/Data/Sentinel/south_jutland_jan/S1B_IW_SLC__1SDV_20200214T170846_20200214T170913_020268_026619_0A0D.SAFE"
master_data_path, master_meta_path, master_cal_path = Load.slc_paths(master_folder, "VV",3)
# Out:
# ("/Users/simon/Data/Sentinel/south_jutland_jan/S1B_IW_SLC__1SDV_20200214T170846_20200214T170913_020268_026619_0A0D.SAFE/measurement/s1b-iw3-slc-vv-20200214t170846-20200214t170911-020268-026619-006.tiff", "/Users/simon/Data/Sentinel/south_jutland_jan/S1B_IW_SLC__1SDV_20200214T170846_20200214T170913_020268_026619_0A0D.SAFE/annotation/s1b-iw3-slc-vv-20200214t170846-20200214t170911-020268-026619-006.xml", "/Users/simon/Data/Sentinel/south_jutland_jan/S1B_IW_SLC__1SDV_20200214T170846_20200214T170913_020268_026619_0A0D.SAFE/annotation/calibration/calibration-s1b-iw3-slc-vv-20200214t170846-20200214t170911-020268-026619-006.xml")

# %%
master_view = [9000:11300,1000:10000];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[end:-1:1,1:4:end])
# Out:
# 2301×2251 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.512311)   …  Gray{Float64}(0.0628496)
#  Gray{Float64}(0.45567)       Gray{Float64}(0.0409729)
#  Gray{Float64}(0.299378)      Gray{Float64}(0.0579445)
#  Gray{Float64}(0.436635)      Gray{Float64}(0.0764598)
#  Gray{Float64}(0.136037)      Gray{Float64}(0.0397496)
#  Gray{Float64}(0.234531)   …  Gray{Float64}(0.0160236)
#  Gray{Float64}(0.0993739)     Gray{Float64}(0.1451)
#  Gray{Float64}(0.233307)      Gray{Float64}(0.0764598)
#  Gray{Float64}(0.595879)      Gray{Float64}(0.104885)
#  Gray{Float64}(0.59765)       Gray{Float64}(0.118584)
#  Gray{Float64}(0.355781)   …  Gray{Float64}(0.198996)
#  Gray{Float64}(0.398315)      Gray{Float64}(0.158625)
#  Gray{Float64}(0.227738)      Gray{Float64}(0.0924765)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.550392)      Gray{Float64}(0.0133324)
#  Gray{Float64}(0.834516)   …  Gray{Float64}(0.0579445)
# ...

# %%
master_data_path, master_meta_path, master_cal_path = Load.slc_paths(master_folder, "VH",2)
# Out:
# ("/Users/simon/Data/Sentinel/south_jutland_jan/S1B_IW_SLC__1SDV_20200214T170846_20200214T170913_020268_026619_0A0D.SAFE/measurement/s1b-iw2-slc-vh-20200214t170847-20200214t170913-020268-026619-002.tiff", "/Users/simon/Data/Sentinel/south_jutland_jan/S1B_IW_SLC__1SDV_20200214T170846_20200214T170913_020268_026619_0A0D.SAFE/annotation/s1b-iw2-slc-vh-20200214t170847-20200214t170913-020268-026619-002.xml", "/Users/simon/Data/Sentinel/south_jutland_jan/S1B_IW_SLC__1SDV_20200214T170846_20200214T170913_020268_026619_0A0D.SAFE/annotation/calibration/calibration-s1b-iw2-slc-vh-20200214t170847-20200214t170913-020268-026619-002.xml")

# %%
master_view = [10500:12800,16000:25300];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[end:-1:1,1:4:end])
# Out:
# 2301×2326 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.230385)   …  Gray{Float64}(0.186424)
#  Gray{Float64}(0.199581)      Gray{Float64}(0.369225)
#  Gray{Float64}(0.327338)      Gray{Float64}(0.486933)
#  Gray{Float64}(0.205724)      Gray{Float64}(0.518623)
#  Gray{Float64}(0.16935)       Gray{Float64}(0.607741)
#  Gray{Float64}(0.157783)   …  Gray{Float64}(0.580161)
#  Gray{Float64}(0.321815)      Gray{Float64}(0.426306)
#  Gray{Float64}(0.428635)      Gray{Float64}(0.526626)
#  Gray{Float64}(0.268695)      Gray{Float64}(0.260222)
#  Gray{Float64}(0.266275)      Gray{Float64}(0.307414)
#  Gray{Float64}(0.0726487)  …  Gray{Float64}(0.40165)
#  Gray{Float64}(0.219539)      Gray{Float64}(0.165183)
#  Gray{Float64}(0.319486)      Gray{Float64}(0.138634)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.254417)      Gray{Float64}(0.0)
#  Gray{Float64}(0.802617)   …  Gray{Float64}(0.0223139)
#  Gray{Float64}(0.883246)      Gray{Float64}(0.0223139)
# ...

# %%
master_view = [10400:12600,16000:25500];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[end:-1:1,1:4:end])
# Out:
# 2201×2376 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.22567)    Gray{Float64}(0.549784)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.305647)   Gray{Float64}(0.244069)     Gray{Float64}(0.0)
#  Gray{Float64}(0.31951)    Gray{Float64}(0.252353)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0711676)  Gray{Float64}(0.440002)     Gray{Float64}(0.0)
#  Gray{Float64}(0.272025)   Gray{Float64}(0.589647)     Gray{Float64}(0.0)
#  Gray{Float64}(0.304009)   Gray{Float64}(0.706071)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.010778)   Gray{Float64}(0.413544)     Gray{Float64}(0.0)
#  Gray{Float64}(0.353939)   Gray{Float64}(0.308522)     Gray{Float64}(0.0)
#  Gray{Float64}(0.66999)    Gray{Float64}(0.37646)      Gray{Float64}(0.0)
#  Gray{Float64}(0.315779)   Gray{Float64}(0.446293)     Gray{Float64}(0.0)
#  Gray{Float64}(0.084179)   Gray{Float64}(0.293669)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.181506)   Gray{Float64}(0.450722)     Gray{Float64}(0.0)
# ...

# %%
master_view = [6000:8000,4000:16000];
master_data = Load.slc_data(master_data_path,master_view);
SlcUtil.show_img(master_data[end:-1:1,1:4:end])
# Out:
# 2001×3001 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.189346)    …  Gray{Float64}(0.554586)
#  Gray{Float64}(0.320113)       Gray{Float64}(0.352715)
#  Gray{Float64}(0.237706)       Gray{Float64}(0.448051)
#  Gray{Float64}(0.0848817)      Gray{Float64}(0.346326)
#  Gray{Float64}(0.147522)       Gray{Float64}(0.635526)
#  Gray{Float64}(0.14902)     …  Gray{Float64}(1.0)
#  Gray{Float64}(0.207501)       Gray{Float64}(1.0)
#  Gray{Float64}(0.21726)        Gray{Float64}(0.65089)
#  Gray{Float64}(0.268419)       Gray{Float64}(0.246671)
#  Gray{Float64}(0.360465)       Gray{Float64}(0.288789)
#  Gray{Float64}(0.21726)     …  Gray{Float64}(0.422952)
#  Gray{Float64}(0.0993465)      Gray{Float64}(1.0)
#  Gray{Float64}(0.0675629)      Gray{Float64}(0.987711)
#  ⋮                          ⋱  ⋮
#  Gray{Float64}(0.00702486)     Gray{Float64}(0.171499)
#  Gray{Float64}(0.0198693)   …  Gray{Float64}(0.404067)
#  Gray{Float64}(0.121268)       Gray{Float64}(0.340289)
# ...
