# %%
include("../ToolBox/ToolBox.jl")
import FileIO
import JLD
using .ToolBox
using .Geometry
using Colors

# %%
function moasic2normal_view(moasic_view,meta)
    @assert moasic_view[1].start >= meta["burst_meta"]["first_line_mosaic"][1]
    @assert moasic_view[1].stop <= (meta["burst_meta"]["first_line_mosaic"][end] + meta["lines_per_burst"])

    
    start_burst = findlast(
    meta["burst_meta"]["first_line_mosaic"].<= moasic_view[1].start)

    lines_in_first_burst = moasic_view[1].start -meta["burst_meta"]["first_line_mosaic"][start_burst] +1
    line_start = lines_in_first_burst + (start_burst-1)* meta["lines_per_burst"]

    end_burst = 0
    if moasic_view[1].stop < meta["lines_per_burst"]
        end_burst = 1
    else
        end_burst = findlast(
            (meta["burst_meta"]["first_line_mosaic"] .+meta["lines_per_burst"] ).< moasic_view[1].stop)+1
    end

    lines_in_last_burst =  moasic_view[1].stop - meta["burst_meta"]["first_line_mosaic"][end_burst] +1
    line_end = lines_in_last_burst+ (end_burst-1)* meta["lines_per_burst"]
    return [line_start:line_end,moasic_view[2]]
end


function round_2_int(float_number,tol=0.1)
    res = round(Int64,float_number)
    @assert abs(res-float_number)<tol "Rounding not within tolerance"
return res
end

using Dates
function split_large_view(large_view,meta_first,meta_second)
    c = 299792458
    azimuth_frequency =  meta_first["azimuth_frequency"]
    inv_range_pixel_spacing = (2*meta_first["range_sampling_rate"])/c
    delta_r0 = (meta_second["slant_range_time"]-meta_first["slant_range_time"])*c/2
    delta_sample = inv_range_pixel_spacing*delta_r0

    delta_sample = round_2_int(inv_range_pixel_spacing*delta_r0)

    over_lap = meta_first["samples_per_burst"]-delta_sample +1

    delta_minus = 300
    delta_plus = over_lap - delta_minus


    view_first = large_view[1],large_view[2].start:(meta_first["samples_per_burst"]-delta_minus)

    mosaic_view_first = SlcUtil.get_mosaic_view(meta_first,view_first)


    detlta_t0 = convert(Second,(meta_first["t_0"]-meta_second["t_0"]) ).value

    line_t_first_start =  (mosaic_view_first[1].start-1)/azimuth_frequency+meta_first["t_start"]
    line_second_start = round_2_int(1 + ((line_t_first_start+detlta_t0)-meta_second["t_start"])*azimuth_frequency)

    line_t_first_stop =  (mosaic_view_first[1].stop-1)/azimuth_frequency+meta_first["t_start"]
    line_second_stop= round_2_int(1 + ((line_t_first_stop+detlta_t0)-meta_second["t_start"])*azimuth_frequency)


    mosaic_view_second = [line_second_start:line_second_stop,
                        (1+delta_plus): (large_view[2].stop - delta_sample+1)]

    view_second = moasic2normal_view(mosaic_view_second,meta_second)
    return view_first,view_second
end
# Out:
# split_large_view (generic function with 1 method)

# %% [markdown]
# # Mosaic Subswaths

# %%
master_folder = "/home/data/simon/data/117_jutlandS_autumn2019/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE"
slave_folder = "/home/data/simon/data/117_jutlandS_autumn2019/S1A_IW_SLC__1SDV_20191011T170932_20191011T170959_029414_035865_06AB.SAFE"

#dem
dem_path = "/home/data/simon/DEM/denmark.jld";

# pod
master_pod_path = Load.pod_path(master_folder,"/home/data/simon/POE")
slave_pod_path = Load.pod_path(slave_folder,"/home/data/simon/POE");

# %%
polarization = "VV"

# Paths 
data_path2, meta_path2, cal_path2 = Load.slc_paths(master_folder, polarization, 2)
data_path3, meta_path3, cal_path3 = Load.slc_paths(master_folder, polarization, 3);

# %%
meta2 = Load.slc_meta(meta_path2);
meta3 = Load.slc_meta(meta_path3);

# %%
large_view = [2004:5200,18000:30000]
# Out:
# 2-element Array{UnitRange{Int64},1}:
#  2004:5200
#  18000:30000

# %%
view_first,view_second =split_large_view(large_view,meta_first,meta_second);

# %%
data_first = Load.slc_data(data_path2,view_first);
data_first,mosaic_view_first_out = SlcUtil.mosaic(data_first,view_first,meta_first)
data_second = Load.slc_data(data_path3,view_second);
data_second,mosaic_view_second_out = SlcUtil.mosaic(data_second,view_second,meta_second);

# %%
swath_mosaic= hcat(data_first,data_second);
SlcUtil.show_img(swath_mosaic)[:,1:4:end]
# Out:
# 2861×3001 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.116328)   …  Gray{Float64}(0.0363416)
#  Gray{Float64}(0.246233)      Gray{Float64}(0.339361)
#  Gray{Float64}(0.374241)      Gray{Float64}(0.45547)
#  Gray{Float64}(0.391411)      Gray{Float64}(0.21429)
#  Gray{Float64}(0.382537)      Gray{Float64}(0.0485485)
#  Gray{Float64}(0.203642)   …  Gray{Float64}(0.185306)
#  Gray{Float64}(0.315694)      Gray{Float64}(0.461651)
#  Gray{Float64}(0.530081)      Gray{Float64}(0.360525)
#  Gray{Float64}(0.340019)      Gray{Float64}(0.197719)
#  Gray{Float64}(0.167025)      Gray{Float64}(0.565773)
#  Gray{Float64}(0.034329)   …  Gray{Float64}(0.469182)
#  Gray{Float64}(0.588274)      Gray{Float64}(0.218049)
#  Gray{Float64}(0.794991)      Gray{Float64}(0.359028)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.524939)      Gray{Float64}(0.223116)
#  Gray{Float64}(0.460152)   …  Gray{Float64}(0.0676142)
#  Gray{Float64}(0.677118)      Gray{Float64}(0.129785)
#  Gray{Float64}(0.824733)      Gray{Float64}(0.179457)
#  Gray{Float64}(0.436332)      Gray{Float64}(0.153524)
#  Gray{Float64}(0.148751)      Gray{Float64}(0.133793)
#  Gray{Float64}(0.0513947)  …  Gray{Float64}(0.157831)
#  Gray{Float64}(0.225426)      Gray{Float64}(0.0885606)
#  Gray{Float64}(0.229933)      Gray{Float64}(0.114922)
#  Gray{Float64}(0.43388)       Gray{Float64}(0.0573726)
#  Gray{Float64}(0.436099)      Gray{Float64}(0.140244)
#  Gray{Float64}(0.443949)   …  Gray{Float64}(0.0415582)

# %% [markdown]
# # Skrald

# %%
master_view = [4004:7200,18000:3000]
test = SlcUtil.get_mosaic_view(meta_test,master_view)
# Out:
# (3667:6528, 18000:17999)

# %%
large_view = [4004:7200,18000:30000]
meta_first = meta2
meta_second = meta3;

# %%
using Dates

# %%
function round_2_int(float_number,tol=0.1)
    res = round(Int64,float_number)
    @assert abs(res-float_number)<tol "Rounding not within tolerance"
return res
end
# Out:
# round_2_int (generic function with 2 methods)

# %%
inv_range_pixel_spacing*delta_r0
# Out:
# 23856.999999999996

# %%
c = 299792458
azimuth_frequency =  meta_first["azimuth_frequency"]
inv_range_pixel_spacing = (2*meta_first["range_sampling_rate"])/c
delta_r0 = (meta_second["slant_range_time"]-meta_first["slant_range_time"])*c/2
delta_sample = inv_range_pixel_spacing*delta_r0

delta_sample = round_2_int(inv_range_pixel_spacing*delta_r0)

over_lap = meta_first["samples_per_burst"]-delta_sample +1

delta_minus = 300
delta_plus = over_lap - delta_minus


view_first = large_view[1],large_view[2].start:(meta_first["samples_per_burst"]-delta_minus)

mosaic_view_first = SlcUtil.get_mosaic_view(meta_first,view_first)


detlta_t0 = convert(Second,(meta_first["t_0"]-meta_second["t_0"]) ).value

line_t_first_start =  (mosaic_view_first[1].start-1)/azimuth_frequency+meta_first["t_start"]
line_second_start = round_2_int(1 + ((line_t_first_start+detlta_t0)-meta_second["t_start"])*azimuth_frequency)

line_t_first_stop =  (mosaic_view_first[1].stop-1)/azimuth_frequency+meta_first["t_start"]
line_second_stop= round_2_int(1 + ((line_t_first_stop+detlta_t0)-meta_second["t_start"])*azimuth_frequency)


mosaic_view_second = [line_second_start:line_second_stop,
                    (1+delta_plus): (large_view[2].stop - delta_sample+1)]

view_second =moasic2normal_view(mosaic_view_second,meta_second)
# Out:
# 2-element Array{UnitRange{Int64},1}:
#  3547:6758
#  1802:6144

# %%
view_first,view_second =split_large_view(large_view,meta_first,meta_second);

# %%
data_first = Load.slc_data(data_path2,view_first);
data_first,mosaic_view_first_out = SlcUtil.mosaic(data_first,view_first,meta_first)
data_second = Load.slc_data(data_path3,view_second);
data_second,mosaic_view_second_out = SlcUtil.mosaic(data_second,view_second,meta_second);

# %%
mosaic_view_second,mosaic_view_second_out
# Out:
# (UnitRange{Int64}[3201:6062, 1802:6144], (3201:6062, 1802:6144))

# %%
mosaic_view_first,mosaic_view_first_out
# Out:
# ((3667:6528, 18000:25657), (3667:6528, 18000:25657))

# %%
size(data_first),size(data_second)
# Out:
# ((2862, 7658), (2862, 4343))

# %%
swath_mosaic= hcat(data_first,data_second);
SlcUtil.show_img(swath_mosaic)[:,1:4:end]
# Out:
# 2862×3001 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.361625)  …  Gray{Float64}(0.0755269)
#  Gray{Float64}(0.36495)      Gray{Float64}(0.064036)
#  Gray{Float64}(0.504642)     Gray{Float64}(0.138797)
#  Gray{Float64}(0.414168)     Gray{Float64}(0.21027)
#  Gray{Float64}(0.638614)     Gray{Float64}(0.195616)
#  Gray{Float64}(0.538447)  …  Gray{Float64}(0.248174)
#  Gray{Float64}(0.169363)     Gray{Float64}(0.128862)
#  Gray{Float64}(0.305482)     Gray{Float64}(0.171211)
#  Gray{Float64}(0.319926)     Gray{Float64}(0.0503736)
#  Gray{Float64}(0.144178)     Gray{Float64}(0.0509745)
#  Gray{Float64}(0.45024)   …  Gray{Float64}(0.0745802)
#  Gray{Float64}(0.445526)     Gray{Float64}(0.0630778)
#  Gray{Float64}(0.569129)     Gray{Float64}(0.0866661)
#  ⋮                        ⋱  ⋮
#  Gray{Float64}(0.400158)  …  Gray{Float64}(0.807098)
#  Gray{Float64}(0.335233)     Gray{Float64}(0.487642)
#  Gray{Float64}(0.502405)     Gray{Float64}(0.271719)
#  Gray{Float64}(0.279381)     Gray{Float64}(0.349144)
#  Gray{Float64}(0.30308)      Gray{Float64}(0.188696)
#  Gray{Float64}(0.433494)  …  Gray{Float64}(0.62836)
#  Gray{Float64}(0.516275)     Gray{Float64}(0.726499)
#  Gray{Float64}(0.30651)      Gray{Float64}(0.361148)
#  Gray{Float64}(0.401222)     Gray{Float64}(0.12823)
#  Gray{Float64}(0.299035)     Gray{Float64}(0.151121)
#  Gray{Float64}(0.359345)  …  Gray{Float64}(0.565084)
#  Gray{Float64}(0.234332)     Gray{Float64}(0.561299)

# %%
master_view = [4000:6000,15000:25900]
data2 = Load.slc_data(data_path2,master_view);
SlcUtil.show_img(data2)[:,1:4:end]
# Out:
# 2001×2726 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.316069)   …  Gray{Float64}(0.0)
#  Gray{Float64}(0.232795)      Gray{Float64}(0.0)
#  Gray{Float64}(0.349657)      Gray{Float64}(0.0)
#  Gray{Float64}(0.139098)      Gray{Float64}(0.0)
#  Gray{Float64}(0.555753)      Gray{Float64}(0.0)
#  Gray{Float64}(0.596574)   …  Gray{Float64}(0.0)
#  Gray{Float64}(0.39438)       Gray{Float64}(0.0)
#  Gray{Float64}(0.867639)      Gray{Float64}(0.0)
#  Gray{Float64}(0.938523)      Gray{Float64}(0.0)
#  Gray{Float64}(0.489741)      Gray{Float64}(0.0)
#  Gray{Float64}(0.0871397)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.170253)      Gray{Float64}(0.0)
#  Gray{Float64}(0.196064)      Gray{Float64}(0.0)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.353473)      Gray{Float64}(0.0)
#  Gray{Float64}(0.257231)   …  Gray{Float64}(0.0)
#  Gray{Float64}(0.213661)      Gray{Float64}(0.0)
#  Gray{Float64}(0.52855)       Gray{Float64}(0.0)
#  Gray{Float64}(0.604643)      Gray{Float64}(0.0)
#  Gray{Float64}(0.403869)      Gray{Float64}(0.0)
#  Gray{Float64}(0.123308)   …  Gray{Float64}(0.0)
#  Gray{Float64}(0.317452)      Gray{Float64}(0.0)
#  Gray{Float64}(0.31375)       Gray{Float64}(0.0)
#  Gray{Float64}(0.278)         Gray{Float64}(0.00427237)
#  Gray{Float64}(0.0937005)     Gray{Float64}(0.0)
#  Gray{Float64}(0.327053)   …  Gray{Float64}(0.0)

# %%
master_view = [3500:5500,1:10000]
data3 = Load.slc_data(data_path3,master_view);
SlcUtil.show_img(data3)[:,1:4:end]
# Out:
# 2001×2500 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0672547)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.124012)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.106339)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0567402)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0805737)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.108812)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.213739)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.106339)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0145896)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0263018)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0461364)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0206328)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.072948)
#  ⋮                                       ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.5551)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.45313)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.335561)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.101343)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.219148)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.402373)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.866824)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.67132)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.309664)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.268078)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.667823)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.249521)

# %%
master_folder = "/home/data/simon/data/117_jutlandS_autumn2019/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE"
slave_folder = "/home/data/simon/data/117_jutlandS_autumn2019/S1A_IW_SLC__1SDV_20191011T170932_20191011T170959_029414_035865_06AB.SAFE"

#dem
dem_path = "/home/data/simon/DEM/denmark.jld";

# pod
master_pod_path = Load.pod_path(master_folder,"/home/data/simon/POE")
slave_pod_path = Load.pod_path(slave_folder,"/home/data/simon/POE");

# %%
polarization = "VV"
subswath = 3

# Paths 
master_data_path, master_meta_path, master_cal_path = Load.slc_paths(master_folder, polarization, subswath)
slave_data_path, slave_meta_path, slave_cal_path = Load.slc_paths(slave_folder, polarization, subswath);

# %%
master_view = [8000:10000,1200:6000]
# Out:
# 2-element Array{UnitRange{Int64},1}:
#  8000:10000
#  1200:6000

# %%
# load meta and pod
master_meta = Load.slc_meta(master_meta_path);
master_precise_orbit = Load.precise_orbit(master_pod_path,master_meta["t_0"]);
slave_meta = Load.slc_meta(slave_meta_path);
slave_precise_orbit = Load.precise_orbit(slave_pod_path,slave_meta["t_0"]);

meta = (master_meta,slave_meta)
precise_orbit = (master_precise_orbit,slave_precise_orbit);

# %%
pad = 0.1
dem = JLD.load(dem_path);
footprint = SlcUtil.footprint(master_meta, master_view)
latlon_window = ((minimum(footprint[1]), maximum(footprint[1])), (minimum(footprint[2]), maximum(footprint[2])))
idx1 =(latlon_window[1][1] - pad) .<dem["lat"].< (latlon_window[1][2] + pad)
idx2 =(latlon_window[2][1] - pad) .<dem["lon"].< (latlon_window[2][2] + pad)
dem = (dem["lat"][idx1], dem["lon"][idx2], dem["height"][idx1,idx2]);
dem[3][dem[3].<0] .= 40;

# %%
slave_data,flat,lut =  coregister_slave(master_view,slave_data_path,meta,precise_orbit,dem)
slave_data,mosaic_view = SlcUtil.mosaic(slave_data,master_view,meta[1]);
flat,mosaic_view = SlcUtil.mosaic(flat,master_view,meta[1]);

master_data = Load.slc_data(master_data_path,master_view);
master_data,mosaic_view = SlcUtil.mosaic(master_data,master_view,meta[1]);

# %%
kernel = ones(4,14)
complex_coherence, master_intensity, slave_intensity, lines, samples = SlcUtil.complex_coherence(master_data, slave_data, flat, kernel, mosaic_view);

# %%
coherence_img = Gray.(abs.(complex_coherence[1:2:end,150:7:end]))
# Out:
# 911×661 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.613454)  …  Gray{Float64}(0.296911)
#  Gray{Float64}(0.739326)     Gray{Float64}(0.860463)
#  Gray{Float64}(0.780365)     Gray{Float64}(0.946657)
#  Gray{Float64}(0.700583)     Gray{Float64}(0.929183)
#  Gray{Float64}(0.42681)      Gray{Float64}(0.830641)
#  Gray{Float64}(0.44453)   …  Gray{Float64}(0.780618)
#  Gray{Float64}(0.723778)     Gray{Float64}(0.637266)
#  Gray{Float64}(0.741896)     Gray{Float64}(0.596028)
#  Gray{Float64}(0.770649)     Gray{Float64}(0.397245)
#  Gray{Float64}(0.804379)     Gray{Float64}(0.44849)
#  Gray{Float64}(0.850303)  …  Gray{Float64}(0.53891)
#  Gray{Float64}(0.839501)     Gray{Float64}(0.48732)
#  Gray{Float64}(0.704762)     Gray{Float64}(0.64996)
#  ⋮                        ⋱  ⋮
#  Gray{Float64}(0.757001)     Gray{Float64}(0.236748)
#  Gray{Float64}(0.7487)    …  Gray{Float64}(0.34265)
#  Gray{Float64}(0.844853)     Gray{Float64}(0.449437)
#  Gray{Float64}(0.85262)      Gray{Float64}(0.389915)
#  Gray{Float64}(0.832736)     Gray{Float64}(0.34614)
#  Gray{Float64}(0.836466)     Gray{Float64}(0.279355)
#  Gray{Float64}(0.75279)   …  Gray{Float64}(0.350474)
#  Gray{Float64}(0.694205)     Gray{Float64}(0.297983)
#  Gray{Float64}(0.694464)     Gray{Float64}(0.327165)
#  Gray{Float64}(0.642949)     Gray{Float64}(0.169039)
#  Gray{Float64}(0.409506)     Gray{Float64}(0.0614038)
#  Gray{Float64}(0.32617)   …  Gray{Float64}(0.115736)

# %%
intensity = SlcUtil.show_img(master_intensity[1:2:end,1:7:end].-minimum(minimum(master_intensity[1:2:end,1:7:end])))
# Out:
# 911×683 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.205262)  Gray{Float64}(0.163504)  …  Gray{Float64}(0.155632)
#  Gray{Float64}(0.252301)  Gray{Float64}(0.170959)     Gray{Float64}(1.0)
#  Gray{Float64}(0.279253)  Gray{Float64}(0.286218)     Gray{Float64}(1.0)
#  Gray{Float64}(0.308408)  Gray{Float64}(0.362296)     Gray{Float64}(1.0)
#  Gray{Float64}(0.236517)  Gray{Float64}(0.203205)     Gray{Float64}(0.808716)
#  Gray{Float64}(0.145542)  Gray{Float64}(0.127526)  …  Gray{Float64}(0.695526)
#  Gray{Float64}(0.163229)  Gray{Float64}(0.186495)     Gray{Float64}(0.351673)
#  Gray{Float64}(0.174029)  Gray{Float64}(0.185543)     Gray{Float64}(0.274685)
#  Gray{Float64}(0.185784)  Gray{Float64}(0.223604)     Gray{Float64}(0.252119)
#  Gray{Float64}(0.221588)  Gray{Float64}(0.250099)     Gray{Float64}(0.239384)
#  Gray{Float64}(0.189107)  Gray{Float64}(0.222298)  …  Gray{Float64}(0.206338)
#  Gray{Float64}(0.175516)  Gray{Float64}(0.233996)     Gray{Float64}(0.192427)
#  Gray{Float64}(0.212019)  Gray{Float64}(0.210526)     Gray{Float64}(0.177649)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.260601)  Gray{Float64}(0.239207)     Gray{Float64}(0.354236)
#  Gray{Float64}(0.27107)   Gray{Float64}(0.300142)  …  Gray{Float64}(0.293824)
#  Gray{Float64}(0.270758)  Gray{Float64}(0.318357)     Gray{Float64}(0.243912)
#  Gray{Float64}(0.242832)  Gray{Float64}(0.262202)     Gray{Float64}(0.35289)
#  Gray{Float64}(0.24296)   Gray{Float64}(0.278955)     Gray{Float64}(0.377985)
#  Gray{Float64}(0.239735)  Gray{Float64}(0.289101)     Gray{Float64}(0.241102)
#  Gray{Float64}(0.283638)  Gray{Float64}(0.291312)  …  Gray{Float64}(0.246685)
#  Gray{Float64}(0.290475)  Gray{Float64}(0.309331)     Gray{Float64}(0.300418)
#  Gray{Float64}(0.237696)  Gray{Float64}(0.239754)     Gray{Float64}(0.311238)
#  Gray{Float64}(0.186363)  Gray{Float64}(0.176762)     Gray{Float64}(0.287903)
#  Gray{Float64}(0.183243)  Gray{Float64}(0.180293)     Gray{Float64}(0.249561)
#  Gray{Float64}(0.169643)  Gray{Float64}(0.150081)  …  Gray{Float64}(0.353124)

# %%
2+4
# Out:
# 6
