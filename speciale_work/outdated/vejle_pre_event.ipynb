# %%
include("../ToolBox/ToolBox.jl")
import JLD
import FileIO
using .ToolBox
using .Geometry
using Colors

# %%
# Paths 
master_data_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/measurement/s1a-iw3-slc-vv-20190929t170934-20190929t170959-029239-035263-006.tiff"
master_meta_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/annotation/s1a-iw3-slc-vv-20190929t170934-20190929t170959-029239-035263-006.xml"
master_pod_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_OPER_AUX_POEORB_OPOD_20191019T120656_V20190928T225942_20190930T005942.EOF"

slave_data_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190917T170931_20190917T170958_029064_034C5E_2484.SAFE/measurement/s1a-iw3-slc-vv-20190917t170933-20190917t170958-029064-034c5e-006.tiff"
slave_meta_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190917T170931_20190917T170958_029064_034C5E_2484.SAFE/annotation/s1a-iw3-slc-vv-20190917t170933-20190917t170958-029064-034c5e-006.xml"
slave_pod_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_OPER_AUX_POEORB_OPOD_20191007T120623_V20190916T225942_20190918T005942.EOF"
#dem
dem_path = "/Users/simon/Data/DEM/denmark.jld";

# %%
master_view = [8000:10000,1200:6000]
# Out:
# 2-element Array{UnitRange{Int64},1}:
#  8000:10000
#  1200:6000

# %%
# load meta and pod
master_meta = Load.slc_meta(master_meta_path);
master_precise_orbit = Load.precise_orbit(master_pod_path,master_meta["t_0"]);
slave_meta = Load.slc_meta(slave_meta_path);
slave_precise_orbit = Load.precise_orbit(slave_pod_path,slave_meta["t_0"]);

meta = (master_meta,slave_meta)
precise_orbit = (master_precise_orbit,slave_precise_orbit);

# %%
pad = 0.1
dem = JLD.load(dem_path);
footprint = SlcUtil.footprint(master_meta, master_view)
latlon_window = ((minimum(footprint[1]), maximum(footprint[1])), (minimum(footprint[2]), maximum(footprint[2])))
idx1 =(latlon_window[1][1] - pad) .<dem["lat"].< (latlon_window[1][2] + pad)
idx2 =(latlon_window[2][1] - pad) .<dem["lon"].< (latlon_window[2][2] + pad)
dem = (dem["lat"][idx1], dem["lon"][idx2], dem["height"][idx1,idx2]);
dem[3][dem[3].<0] .= 0;

# %%
slave_data,flat,lut =  coregister_slave(master_view,slave_data_path,meta,precise_orbit,dem)
slave_data,mosaic_view = SlcUtil.mosaic(slave_data,master_view,meta[1]);
flat,mosaic_view = SlcUtil.mosaic(flat,master_view,meta[1]);

master_data = Load.slc_data(master_data_path,master_view);
master_data,mosaic_view = SlcUtil.mosaic(master_data,master_view,meta[1]);

# %%
kernel = ones(4,14)
complex_coherence, master_intensity, slave_intensity, lines, samples = SlcUtil.complex_coherence(master_data, slave_data, flat, kernel, mosaic_view);

# %%
coherence_img = Gray.(abs.(complex_coherence[1:2:end,150:7:end]))
# Out:
# 911×661 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.153438)   …  Gray{Float64}(0.188928)
#  Gray{Float64}(0.268414)      Gray{Float64}(0.75223)
#  Gray{Float64}(0.225524)      Gray{Float64}(0.854398)
#  Gray{Float64}(0.13719)       Gray{Float64}(0.885516)
#  Gray{Float64}(0.190273)      Gray{Float64}(0.308159)
#  Gray{Float64}(0.0769911)  …  Gray{Float64}(0.101331)
#  Gray{Float64}(0.190058)      Gray{Float64}(0.514668)
#  Gray{Float64}(0.112198)      Gray{Float64}(0.479088)
#  Gray{Float64}(0.389453)      Gray{Float64}(0.420575)
#  Gray{Float64}(0.376742)      Gray{Float64}(0.45602)
#  Gray{Float64}(0.360283)   …  Gray{Float64}(0.464321)
#  Gray{Float64}(0.216647)      Gray{Float64}(0.44284)
#  Gray{Float64}(0.15431)       Gray{Float64}(0.507711)
#  ⋮                         ⋱  ⋮
#  Gray{Float64}(0.104)         Gray{Float64}(0.123046)
#  Gray{Float64}(0.203069)   …  Gray{Float64}(0.355337)
#  Gray{Float64}(0.138974)      Gray{Float64}(0.39949)
#  Gray{Float64}(0.142161)      Gray{Float64}(0.394336)
#  Gray{Float64}(0.357119)      Gray{Float64}(0.274254)
#  Gray{Float64}(0.293468)      Gray{Float64}(0.156877)
#  Gray{Float64}(0.0938611)  …  Gray{Float64}(0.361936)
#  Gray{Float64}(0.210962)      Gray{Float64}(0.449661)
#  Gray{Float64}(0.225711)      Gray{Float64}(0.177614)
#  Gray{Float64}(0.253121)      Gray{Float64}(0.209698)
#  Gray{Float64}(0.363002)      Gray{Float64}(0.295883)
#  Gray{Float64}(0.122037)   …  Gray{Float64}(0.264549)

# %%
intensity = SlcUtil.show_img(master_intensity[1:2:end,1:7:end].-minimum(minimum(master_intensity[1:2:end,1:7:end])))
# Out:
# 911×683 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.205262)  Gray{Float64}(0.163504)  …  Gray{Float64}(0.155632)
#  Gray{Float64}(0.252301)  Gray{Float64}(0.170959)     Gray{Float64}(1.0)
#  Gray{Float64}(0.279253)  Gray{Float64}(0.286218)     Gray{Float64}(1.0)
#  Gray{Float64}(0.308408)  Gray{Float64}(0.362296)     Gray{Float64}(1.0)
#  Gray{Float64}(0.236517)  Gray{Float64}(0.203205)     Gray{Float64}(0.808716)
#  Gray{Float64}(0.145542)  Gray{Float64}(0.127526)  …  Gray{Float64}(0.695526)
#  Gray{Float64}(0.163229)  Gray{Float64}(0.186495)     Gray{Float64}(0.351673)
#  Gray{Float64}(0.174029)  Gray{Float64}(0.185543)     Gray{Float64}(0.274685)
#  Gray{Float64}(0.185784)  Gray{Float64}(0.223604)     Gray{Float64}(0.252119)
#  Gray{Float64}(0.221588)  Gray{Float64}(0.250099)     Gray{Float64}(0.239384)
#  Gray{Float64}(0.189107)  Gray{Float64}(0.222298)  …  Gray{Float64}(0.206338)
#  Gray{Float64}(0.175516)  Gray{Float64}(0.233996)     Gray{Float64}(0.192427)
#  Gray{Float64}(0.212019)  Gray{Float64}(0.210526)     Gray{Float64}(0.177649)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.260601)  Gray{Float64}(0.239207)     Gray{Float64}(0.354236)
#  Gray{Float64}(0.27107)   Gray{Float64}(0.300142)  …  Gray{Float64}(0.293824)
#  Gray{Float64}(0.270758)  Gray{Float64}(0.318357)     Gray{Float64}(0.243912)
#  Gray{Float64}(0.242832)  Gray{Float64}(0.262202)     Gray{Float64}(0.35289)
#  Gray{Float64}(0.24296)   Gray{Float64}(0.278955)     Gray{Float64}(0.377985)
#  Gray{Float64}(0.239735)  Gray{Float64}(0.289101)     Gray{Float64}(0.241102)
#  Gray{Float64}(0.283638)  Gray{Float64}(0.291312)  …  Gray{Float64}(0.246685)
#  Gray{Float64}(0.290475)  Gray{Float64}(0.309331)     Gray{Float64}(0.300418)
#  Gray{Float64}(0.237696)  Gray{Float64}(0.239754)     Gray{Float64}(0.311238)
#  Gray{Float64}(0.186363)  Gray{Float64}(0.176762)     Gray{Float64}(0.287903)
#  Gray{Float64}(0.183243)  Gray{Float64}(0.180293)     Gray{Float64}(0.249561)
#  Gray{Float64}(0.169643)  Gray{Float64}(0.150081)  …  Gray{Float64}(0.353124)

# %%
 SlcUtil.show_img(slave_intensity[1:2:end,1:7:end].-minimum(minimum(master_intensity[1:2:end,1:7:end])))
# Out:
# 911×683 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.219753)   …  Gray{Float64}(0.172322)
#  Gray{Float64}(0.269517)      Gray{Float64}(0.917752)
#  Gray{Float64}(0.247439)      Gray{Float64}(1.0)
#  Gray{Float64}(0.26378)       Gray{Float64}(1.0)
#  Gray{Float64}(0.236366)      Gray{Float64}(0.628751)
#  Gray{Float64}(0.202811)   …  Gray{Float64}(0.428002)
#  Gray{Float64}(0.221274)      Gray{Float64}(0.424883)
#  Gray{Float64}(0.173109)      Gray{Float64}(0.454226)
#  Gray{Float64}(0.136751)      Gray{Float64}(0.393496)
#  Gray{Float64}(0.171347)      Gray{Float64}(0.326988)
#  Gray{Float64}(0.160618)   …  Gray{Float64}(0.225587)
#  Gray{Float64}(0.181405)      Gray{Float64}(0.203043)
#  Gray{Float64}(0.216748)      Gray{Float64}(0.181252)
#  ⋮                         ⋱
#  Gray{Float64}(0.121649)      Gray{Float64}(0.110591)
#  Gray{Float64}(0.0956889)  …  Gray{Float64}(0.128225)
#  Gray{Float64}(0.143066)      Gray{Float64}(0.145715)
#  Gray{Float64}(0.148708)      Gray{Float64}(0.172957)
#  Gray{Float64}(0.120273)      Gray{Float64}(0.186617)
#  Gray{Float64}(0.085706)      Gray{Float64}(0.130656)
#  Gray{Float64}(0.0568334)  …  Gray{Float64}(0.13328)
#  Gray{Float64}(0.0824843)     Gray{Float64}(0.187915)
#  Gray{Float64}(0.114363)      Gray{Float64}(0.156625)
#  Gray{Float64}(0.0971014)     Gray{Float64}(0.121517)
#  Gray{Float64}(0.0941674)     Gray{Float64}(0.104106)
#  Gray{Float64}(0.145186)   …  Gray{Float64}(0.117969)

# %%
JLD.save("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/pre_master_VV.jld", "data", master_intensity)
JLD.save("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/pre_coherence_VV.jld", "data", complex_coherence)
JLD.save("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/pre_slave_VV.jld", "data", slave_intensity)
JLD.save("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/pre_line_sample.jld", "lines", lines, "samples", samples)
