# %%
include("../ToolBox/ToolBox.jl")
import JLD
import FileIO
using .ToolBox
using .Geometry
using Colors

# %%
# Paths 
master_data_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/measurement/s1a-iw3-slc-vh-20190929t170934-20190929t170959-029239-035263-003.tiff"
master_meta_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20190929T170932_20190929T170959_029239_035263_C3F9.SAFE/annotation/s1a-iw3-slc-vh-20190929t170934-20190929t170959-029239-035263-003.xml"
master_pod_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_OPER_AUX_POEORB_OPOD_20191019T120656_V20190928T225942_20190930T005942.EOF"

slave_data_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20191011T170932_20191011T170959_029414_035865_06AB.SAFE/measurement/s1a-iw3-slc-vh-20191011t170933-20191011t170959-029414-035865-003.tiff"
slave_meta_path = "//Users/simon/Data/Sentinel/vejle_oktober/S1A_IW_SLC__1SDV_20191011T170932_20191011T170959_029414_035865_06AB.SAFE/annotation/s1a-iw3-slc-vh-20191011t170933-20191011t170959-029414-035865-003.xml"
slave_pod_path = "/Users/simon/Data/Sentinel/vejle_oktober/S1A_OPER_AUX_POEORB_OPOD_20191031T120708_V20191010T225942_20191012T005942.EOF"
#dem
dem_path = "/Users/simon/Data/DEM/denmark.jld";

# %%
master_view = [8000:10000,1200:6000]
# Out:
# 2-element Array{UnitRange{Int64},1}:
#  8000:10000
#  1200:6000

# %%
# load meta and pod
master_meta = Load.slc_meta(master_meta_path);
master_precise_orbit = Load.precise_orbit(master_pod_path,master_meta["t_0"]);
slave_meta = Load.slc_meta(slave_meta_path);
slave_precise_orbit = Load.precise_orbit(slave_pod_path,slave_meta["t_0"]);

meta = (master_meta,slave_meta)
precise_orbit = (master_precise_orbit,slave_precise_orbit);

# %%
pad = 0.1
dem = JLD.load(dem_path);
footprint = SlcUtil.footprint(master_meta, master_view)
latlon_window = ((minimum(footprint[1]), maximum(footprint[1])), (minimum(footprint[2]), maximum(footprint[2])))
idx1 =(latlon_window[1][1] - pad) .<dem["lat"].< (latlon_window[1][2] + pad)
idx2 =(latlon_window[2][1] - pad) .<dem["lon"].< (latlon_window[2][2] + pad)
dem = (dem["lat"][idx1], dem["lon"][idx2], dem["height"][idx1,idx2]);
dem[3][dem[3].<0] .= 0;

# %%
lut = JLD.load("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/co_lut.jld","lut");

# %%
slave_data,flat,lut =  coregister_slave(master_view,slave_data_path,meta,precise_orbit,dem,lut)
slave_data,mosaic_view = SlcUtil.mosaic(slave_data,master_view,meta[1]);
flat,mosaic_view = SlcUtil.mosaic(flat,master_view,meta[1]);

master_data = Load.slc_data(master_data_path,master_view);
master_data,mosaic_view = SlcUtil.mosaic(master_data,master_view,meta[1]);

# %%
kernel = ones(4,14)
complex_coherence, master_intensity, slave_intensity, lines, samples = SlcUtil.complex_coherence(master_data, slave_data, flat, kernel, mosaic_view);

# %%
coherence_img = Gray.(abs.(complex_coherence[1:2:end,1:7:end]))
# Out:
# 911×683 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.136412)  …  Gray{Float64}(0.542615)
#  Gray{Float64}(0.140636)     Gray{Float64}(0.630135)
#  Gray{Float64}(0.25544)      Gray{Float64}(0.752764)
#  Gray{Float64}(0.391812)     Gray{Float64}(0.591624)
#  Gray{Float64}(0.470688)     Gray{Float64}(0.510613)
#  Gray{Float64}(0.564714)  …  Gray{Float64}(0.494369)
#  Gray{Float64}(0.632134)     Gray{Float64}(0.280904)
#  Gray{Float64}(0.656717)     Gray{Float64}(0.206522)
#  Gray{Float64}(0.446988)     Gray{Float64}(0.320096)
#  Gray{Float64}(0.281691)     Gray{Float64}(0.469734)
#  Gray{Float64}(0.290473)  …  Gray{Float64}(0.432321)
#  Gray{Float64}(0.082514)     Gray{Float64}(0.616027)
#  Gray{Float64}(0.285627)     Gray{Float64}(0.681576)
#  ⋮                        ⋱
#  Gray{Float64}(0.549718)     Gray{Float64}(0.0722397)
#  Gray{Float64}(0.402075)  …  Gray{Float64}(0.248467)
#  Gray{Float64}(0.276002)     Gray{Float64}(0.242258)
#  Gray{Float64}(0.460813)     Gray{Float64}(0.0391147)
#  Gray{Float64}(0.561578)     Gray{Float64}(0.114876)
#  Gray{Float64}(0.443002)     Gray{Float64}(0.368028)
#  Gray{Float64}(0.253748)  …  Gray{Float64}(0.329696)
#  Gray{Float64}(0.322542)     Gray{Float64}(0.105238)
#  Gray{Float64}(0.404052)     Gray{Float64}(0.176069)
#  Gray{Float64}(0.167395)     Gray{Float64}(0.400652)
#  Gray{Float64}(0.226207)     Gray{Float64}(0.277118)
#  Gray{Float64}(0.250663)  …  Gray{Float64}(0.181744)

# %%
intensity = SlcUtil.show_img(master_intensity[1:2:end,1:7:end].-minimum(minimum(master_intensity[1:2:end,1:7:end])))
# Out:
# 911×683 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.395335)  Gray{Float64}(0.36429)   …  Gray{Float64}(0.611585)
#  Gray{Float64}(0.461613)  Gray{Float64}(0.463338)     Gray{Float64}(0.855628)
#  Gray{Float64}(0.477129)  Gray{Float64}(0.490075)     Gray{Float64}(0.774423)
#  Gray{Float64}(0.505369)  Gray{Float64}(0.537133)     Gray{Float64}(0.4894)
#  Gray{Float64}(0.589555)  Gray{Float64}(0.787443)     Gray{Float64}(0.51553)
#  Gray{Float64}(0.865248)  Gray{Float64}(1.0)       …  Gray{Float64}(0.410878)
#  Gray{Float64}(0.844027)  Gray{Float64}(0.844213)     Gray{Float64}(0.290913)
#  Gray{Float64}(0.73896)   Gray{Float64}(0.709391)     Gray{Float64}(0.314452)
#  Gray{Float64}(0.613749)  Gray{Float64}(0.651765)     Gray{Float64}(0.414662)
#  Gray{Float64}(0.390981)  Gray{Float64}(0.662276)     Gray{Float64}(0.345265)
#  Gray{Float64}(0.251936)  Gray{Float64}(0.631673)  …  Gray{Float64}(0.19189)
#  Gray{Float64}(0.29868)   Gray{Float64}(0.374588)     Gray{Float64}(0.263335)
#  Gray{Float64}(0.54391)   Gray{Float64}(0.32715)      Gray{Float64}(0.354174)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.208262)  Gray{Float64}(0.19984)      Gray{Float64}(0.399687)
#  Gray{Float64}(0.181205)  Gray{Float64}(0.130229)  …  Gray{Float64}(0.323011)
#  Gray{Float64}(0.15124)   Gray{Float64}(0.12974)      Gray{Float64}(0.38734)
#  Gray{Float64}(0.214759)  Gray{Float64}(0.216533)     Gray{Float64}(0.490865)
#  Gray{Float64}(0.237598)  Gray{Float64}(0.267604)     Gray{Float64}(0.453716)
#  Gray{Float64}(0.154074)  Gray{Float64}(0.194629)     Gray{Float64}(0.455307)
#  Gray{Float64}(0.160588)  Gray{Float64}(0.177711)  …  Gray{Float64}(0.384215)
#  Gray{Float64}(0.234766)  Gray{Float64}(0.324378)     Gray{Float64}(0.444047)
#  Gray{Float64}(0.224119)  Gray{Float64}(0.335091)     Gray{Float64}(0.47796)
#  Gray{Float64}(0.137107)  Gray{Float64}(0.208376)     Gray{Float64}(0.377206)
#  Gray{Float64}(0.181328)  Gray{Float64}(0.312905)     Gray{Float64}(0.423978)
#  Gray{Float64}(0.348709)  Gray{Float64}(0.473143)  …  Gray{Float64}(0.374396)

# %%
 SlcUtil.show_img(slave_intensity[1:2:end,1:7:end].-minimum(minimum(master_intensity[1:2:end,1:7:end])))
# Out:
# 911×683 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.327648)  Gray{Float64}(0.316357)  …  Gray{Float64}(0.467151)
#  Gray{Float64}(0.437214)  Gray{Float64}(0.376765)     Gray{Float64}(0.60039)
#  Gray{Float64}(0.782496)  Gray{Float64}(0.592868)     Gray{Float64}(0.532415)
#  Gray{Float64}(0.864064)  Gray{Float64}(0.810015)     Gray{Float64}(0.383992)
#  Gray{Float64}(0.622377)  Gray{Float64}(0.732846)     Gray{Float64}(0.685199)
#  Gray{Float64}(0.554722)  Gray{Float64}(0.48208)   …  Gray{Float64}(0.63477)
#  Gray{Float64}(0.622354)  Gray{Float64}(0.52423)      Gray{Float64}(0.332585)
#  Gray{Float64}(0.716059)  Gray{Float64}(0.791034)     Gray{Float64}(0.358079)
#  Gray{Float64}(0.612506)  Gray{Float64}(0.705035)     Gray{Float64}(0.342079)
#  Gray{Float64}(0.392276)  Gray{Float64}(0.520154)     Gray{Float64}(0.277394)
#  Gray{Float64}(0.312091)  Gray{Float64}(0.416268)  …  Gray{Float64}(0.178009)
#  Gray{Float64}(0.387298)  Gray{Float64}(0.25955)      Gray{Float64}(0.268409)
#  Gray{Float64}(0.516629)  Gray{Float64}(0.335674)     Gray{Float64}(0.324555)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.25592)   Gray{Float64}(0.297184)     Gray{Float64}(0.328894)
#  Gray{Float64}(0.400864)  Gray{Float64}(0.38649)   …  Gray{Float64}(0.447604)
#  Gray{Float64}(0.400905)  Gray{Float64}(0.391575)     Gray{Float64}(0.462099)
#  Gray{Float64}(0.369721)  Gray{Float64}(0.402888)     Gray{Float64}(0.464435)
#  Gray{Float64}(0.420348)  Gray{Float64}(0.401437)     Gray{Float64}(0.523507)
#  Gray{Float64}(0.395034)  Gray{Float64}(0.304002)     Gray{Float64}(0.479342)
#  Gray{Float64}(0.334307)  Gray{Float64}(0.263826)  …  Gray{Float64}(0.334766)
#  Gray{Float64}(0.288907)  Gray{Float64}(0.293814)     Gray{Float64}(0.318137)
#  Gray{Float64}(0.292204)  Gray{Float64}(0.344763)     Gray{Float64}(0.387993)
#  Gray{Float64}(0.304261)  Gray{Float64}(0.440252)     Gray{Float64}(0.393085)
#  Gray{Float64}(0.387553)  Gray{Float64}(0.406658)     Gray{Float64}(0.417054)
#  Gray{Float64}(0.47025)   Gray{Float64}(0.40214)   …  Gray{Float64}(0.464379)

# %%
JLD.save("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/co_coherence_VH.jld", "data", complex_coherence)
JLD.save("/Users/simon/Data/Sentinel/vejle_oktober/multilooked/co_intens_VH.jld", "data", slave_intensity)
