# %%
include("../ToolBox/ToolBox.jl")
using .ToolBox

# %%
folder = "/home/data/simon/data"
# Out:
# "/home/data/simon/data"

# %%
target_folder = "/home/data/simon/data/177_jutlandS_winter2020" 
zip_files = [
    "S1A_IW_SLC__1SDV_20200208T170928_20200208T170956_031164_03953C_E56D.zip",
    "S1A_IW_SLC__1SDV_20200220T170928_20200220T170955_031339_039B3F_8FCB.zip",
    "S1B_IW_SLC__1SDV_20200214T170846_20200214T170913_020268_026619_0A0D.zip"
]
Load.unzip(zip_files,folder,target_folder,true);
# Out:
# Archive:  /home/data/simon/data/S1A_IW_SLC__1SDV_20200208T170928_20200208T170956_031164_03953C_E56D.zip
#    creating: /home/data/simon/data/177_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200208T170928_20200208T170956_031164_03953C_E56D.SAFE/
#    creating: /home/data/simon/data/177_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200208T170928_20200208T170956_031164_03953C_E56D.SAFE/support/
#   inflating: /home/data/simon/data/177_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200208T170928_20200208T170956_031164_03953C_E56D.SAFE/support/s1-level-1-calibration.xsd
#   inflating: /home/data/simon/data/177_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200208T170928_20200208T170956_031164_03953C_E56D.SAFE/support/s1-level-1-product.xsd
#   inflating: /home/data/simon/data/177_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200208T170928_20200208T170956_031164_03953C_E56D.SAFE/support/s1-object-types.xsd
# ...

# %%
target_folder = "/home/data/simon/data/177_jutlandN_winter2020" 
zip_files = [
    "S1A_IW_SLC__1SDV_20200220T170953_20200220T171020_031339_039B3F_3F03.zip",
    "S1B_IW_SLC__1SDV_20200214T170910_20200214T170937_020268_026619_4C43.zip",
    "S1A_IW_SLC__1SDV_20200208T170953_20200208T171020_031164_03953C_01FB.zip"
]
Load.unzip(zip_files,folder,target_folder,true);
# Out:
# Archive:  /home/data/simon/data/S1A_IW_SLC__1SDV_20200220T170953_20200220T171020_031339_039B3F_3F03.zip
#    creating: /home/data/simon/data/177_jutlandN_winter2020/S1A_IW_SLC__1SDV_20200220T170953_20200220T171020_031339_039B3F_3F03.SAFE/
#    creating: /home/data/simon/data/177_jutlandN_winter2020/S1A_IW_SLC__1SDV_20200220T170953_20200220T171020_031339_039B3F_3F03.SAFE/support/
#   inflating: /home/data/simon/data/177_jutlandN_winter2020/S1A_IW_SLC__1SDV_20200220T170953_20200220T171020_031339_039B3F_3F03.SAFE/support/s1-level-1-calibration.xsd
#   inflating: /home/data/simon/data/177_jutlandN_winter2020/S1A_IW_SLC__1SDV_20200220T170953_20200220T171020_031339_039B3F_3F03.SAFE/support/s1-level-1-product.xsd
#   inflating: /home/data/simon/data/177_jutlandN_winter2020/S1A_IW_SLC__1SDV_20200220T170953_20200220T171020_031339_039B3F_3F03.SAFE/support/s1-object-types.xsd
# ...

# %%
target_folder = "/home/data/simon/data/66_fyn_winter2020" 
zip_files = [
    "S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.zip",
    "S1B_IW_SLC__1SDV_20200211T053200_20200211T053227_020217_026479_5817.zip",
    "S1A_IW_SLC__1SDV_20200205T053252_20200205T053319_031113_039360_7E5C.zip"
]
Load.unzip(zip_files,folder,target_folder,true);
# Out:
# Archive:  /home/data/simon/data/S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.zip
#    creating: /home/data/simon/data/66_fyn_winter2020/S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.SAFE/
#    creating: /home/data/simon/data/66_fyn_winter2020/S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.SAFE/support/
#   inflating: /home/data/simon/data/66_fyn_winter2020/S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.SAFE/support/s1-level-1-calibration.xsd
#   inflating: /home/data/simon/data/66_fyn_winter2020/S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.SAFE/support/s1-level-1-product.xsd
#   inflating: /home/data/simon/data/66_fyn_winter2020/S1A_IW_SLC__1SDV_20200217T053252_20200217T053319_031288_03996E_8F3C.SAFE/support/s1-object-types.xsd
# ...

# %%
target_folder = "/home/data/simon/data/117_jutlandS_winter2020" 
zip_files = [
    "S1A_IW_SLC__1SDV_20200115T170929_20200115T170956_030814_0388F3_B9B4.zip",
 "S1B_IW_SLC__1SDV_20200121T170846_20200121T170913_019918_025ACD_1581.zip"
]
Load.unzip(zip_files,folder,target_folder,true);
# Out:
# Archive:  /home/data/simon/data/S1A_IW_SLC__1SDV_20200115T170929_20200115T170956_030814_0388F3_B9B4.zip
#    creating: /home/data/simon/data/117_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200115T170929_20200115T170956_030814_0388F3_B9B4.SAFE/
#    creating: /home/data/simon/data/117_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200115T170929_20200115T170956_030814_0388F3_B9B4.SAFE/support/
#   inflating: /home/data/simon/data/117_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200115T170929_20200115T170956_030814_0388F3_B9B4.SAFE/support/s1-level-1-calibration.xsd
#   inflating: /home/data/simon/data/117_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200115T170929_20200115T170956_030814_0388F3_B9B4.SAFE/support/s1-level-1-product.xsd
#   inflating: /home/data/simon/data/117_jutlandS_winter2020/S1A_IW_SLC__1SDV_20200115T170929_20200115T170956_030814_0388F3_B9B4.SAFE/support/s1-object-types.xsd
# ...

# %%
target_folder = "/home/data/simon/data/66_fyn_winter2020" 
zip_files = [
     "S1A_IW_SLC__1SDV_20200112T053253_20200112T053320_030763_03871C_58BD.zip",
 "S1A_IW_SLC__1SDV_20200124T053252_20200124T053319_030938_038D40_F5BF.zip",
 "S1B_IW_SLC__1SDV_20200106T053201_20200106T053228_019692_025399_03F7.zip",
 "S1B_IW_SLC__1SDV_20200118T053200_20200118T053227_019867_02592E_D5D2.zip",
 "S1B_IW_SLC__1SDV_20200130T053200_20200130T053227_020042_025EC3_9D61.zip"
]
Load.unzip(zip_files,folder,target_folder,true);
# Out:
# Archive:  /home/data/simon/data/S1A_IW_SLC__1SDV_20200112T053253_20200112T053320_030763_03871C_58BD.zip
#    creating: /home/data/simon/data/66_fyn_winter2020/S1A_IW_SLC__1SDV_20200112T053253_20200112T053320_030763_03871C_58BD.SAFE/
#    creating: /home/data/simon/data/66_fyn_winter2020/S1A_IW_SLC__1SDV_20200112T053253_20200112T053320_030763_03871C_58BD.SAFE/support/
#   inflating: /home/data/simon/data/66_fyn_winter2020/S1A_IW_SLC__1SDV_20200112T053253_20200112T053320_030763_03871C_58BD.SAFE/support/s1-level-1-calibration.xsd
#   inflating: /home/data/simon/data/66_fyn_winter2020/S1A_IW_SLC__1SDV_20200112T053253_20200112T053320_030763_03871C_58BD.SAFE/support/s1-level-1-product.xsd
#   inflating: /home/data/simon/data/66_fyn_winter2020/S1A_IW_SLC__1SDV_20200112T053253_20200112T053320_030763_03871C_58BD.SAFE/support/s1-object-types.xsd
# ...
