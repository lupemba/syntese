# %%
import FileIO
include("../path.jl")
include("../ToolBox/ToolBox.jl")
using .ToolBox
using .Geometry

# %%
master_meta = Load.slc_meta(master_meta_path);

# %%
SlcUtil.original_view(master_meta)
# Out:
# 2-element Array{UnitRange{Int64},1}:
#  1:15240
#  1:25330

# %%
master_view = [1:15240,1:25330]
master_data = Load.slc_data(master_data_path,master_view);

# %%
img = SlcUtil.show_img(master_data)
# Out:
# 15240×25330 Array{Gray{Float64},2} with eltype ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  ⋮                                       ⋱
# ...

# %%
#FileIO.save("image_vv_master.jpg", img )
# Out:
# ┌ Warning: QuartzImageIO: Mapping to the storage type failed.
# │ Perhaps your data had out-of-range values?
# │ Try `map(clamp01nan, img)` to clamp values to a valid range.
# └ @ QuartzImageIO /Users/simon/.julia/packages/QuartzImageIO/AjiIs/src/QuartzImageIO.jl:227
# ┌ Info: Recompiling stale cache file /Users/simon/.julia/compiled/v1.0/ImageMagick/0LbNX.ji for ImageMagick [6218d12a-5da1-5696-b52f-db25d2ecc6d1]
# └ @ Base loading.jl:1190
# All errors:
# ...
# ArgumentError: element type FixedPointNumbers.Normed{UInt8,8} is an 8-bit type representing 256 values from 0.0 to 1.0,
#   but the values (1.0624408161421879,) do not lie within this range.
#   See the READMEs for FixedPointNumbers and ColorTypes for more information.
# ...
# InitError:
# Errors encountered while saving "image_vv_master.jpg".
# UndefVarError: libwand not defined
# during initialization of module ImageMagick
# ...
# Fatal error:
# ...
