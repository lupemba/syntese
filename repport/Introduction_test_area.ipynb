# %%
include("../path.jl")
include("../ToolBox/ToolBox.jl")
import FileIO
using .ToolBox

# %%
master_view = [2000:6000,1000:9000]
master_data = Load.slc_data(master_data_path,master_view);
master_meta = Load.slc_meta(master_meta_path);
master_data,mosaic_view = SlcUtil.mosaic(master_data,master_view,master_meta);

# %%
img = SlcUtil.show_img(master_data)
# Out:
# 3637×8001 Array{Gray{Float64},2} with eltype ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.561401)  …  Gray{Float64}(0.0941032)
#  Gray{Float64}(0.577969)     Gray{Float64}(0.117888)
#  Gray{Float64}(0.711682)     Gray{Float64}(0.0404812)
#  Gray{Float64}(0.595426)     Gray{Float64}(0.378791)
#  Gray{Float64}(0.370548)     Gray{Float64}(0.407952)
#  Gray{Float64}(0.343952)  …  Gray{Float64}(0.308959)
#  Gray{Float64}(0.461181)     Gray{Float64}(0.285197)
#  Gray{Float64}(0.202406)     Gray{Float64}(0.101203)
#  Gray{Float64}(0.2863)       Gray{Float64}(0.121184)
#  Gray{Float64}(0.298004)     Gray{Float64}(0.154454)
#  Gray{Float64}(0.400153)  …  Gray{Float64}(0.0878687)
#  Gray{Float64}(0.31756)      Gray{Float64}(0.0355043)
#  Gray{Float64}(0.438446)     Gray{Float64}(0.432403)
#  ⋮                        ⋱  ⋮
#  Gray{Float64}(0.734626)  …  Gray{Float64}(0.58407)
#  Gray{Float64}(0.944325)     Gray{Float64}(0.567986)
#  Gray{Float64}(0.567653)     Gray{Float64}(0.0855057)
# ...

# %%
FileIO.save("Introduction_test_area.jpg",img)
