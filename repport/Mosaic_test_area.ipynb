# %%
include("../path.jl")
include("../ToolBox/ToolBox.jl")
import FileIO
using .ToolBox

# %%
master_view = [2000:6000,1000:9000]
master_data = Load.slc_data(master_data_path,master_view);

# %%
img = SlcUtil.show_img(master_data)
# Out:
# 4001×8001 Array{Gray{Float64},2} with eltype ColorTypes.Gray{Float64}:
#  Gray{Float64}(0.565262)  …  Gray{Float64}(0.0947504)
#  Gray{Float64}(0.581943)     Gray{Float64}(0.118699)
#  Gray{Float64}(0.716577)     Gray{Float64}(0.0407596)
#  Gray{Float64}(0.599521)     Gray{Float64}(0.381396)
#  Gray{Float64}(0.373097)     Gray{Float64}(0.410758)
#  Gray{Float64}(0.346318)  …  Gray{Float64}(0.311084)
#  Gray{Float64}(0.464352)     Gray{Float64}(0.287159)
#  Gray{Float64}(0.203798)     Gray{Float64}(0.101899)
#  Gray{Float64}(0.288269)     Gray{Float64}(0.122017)
#  Gray{Float64}(0.300053)     Gray{Float64}(0.155516)
#  Gray{Float64}(0.402905)  …  Gray{Float64}(0.088473)
#  Gray{Float64}(0.319744)     Gray{Float64}(0.0357485)
#  Gray{Float64}(0.441461)     Gray{Float64}(0.435377)
#  ⋮                        ⋱  ⋮
#  Gray{Float64}(0.739679)     Gray{Float64}(0.588087)
#  Gray{Float64}(0.950819)  …  Gray{Float64}(0.571892)
#  Gray{Float64}(0.571557)     Gray{Float64}(0.0860938)
#  Gray{Float64}(0.664408)     Gray{Float64}(0.374678)
#  Gray{Float64}(0.588087)     Gray{Float64}(0.107988)
#  Gray{Float64}(0.303862)     Gray{Float64}(0.124094)
#  Gray{Float64}(0.572255)  …  Gray{Float64}(0.254041)
#  Gray{Float64}(0.522528)     Gray{Float64}(0.143106)
#  Gray{Float64}(0.82812)      Gray{Float64}(0.238472)
#  Gray{Float64}(0.9583)       Gray{Float64}(0.491103)
#  Gray{Float64}(0.429577)     Gray{Float64}(0.231952)
#  Gray{Float64}(0.236184)  …  Gray{Float64}(0.356142)

# %%
FileIO.save("Mosaic_test_area.jpg",img)
